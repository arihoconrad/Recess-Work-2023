# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
load = pd.read_csv("C:\\Users\\DELL\\Desktop\\DATA SCIENCE\\UceResultsBySchool2011-2016.csv")
load
# Out:
#        YEAR      DISTRICT                                              SCHOOL  \
# 0      2011         WAKISO                                 GAYAZA HIGH SCHOOL
# 1      2011         MUKONO                                 NAMILYANGO COLLEGE
# 2      2011         MUKONO                             MT.ST.MARY'S,NAMAGUNGA
# 3      2011         WAKISO                        UGANDA MARTYRS SS,NAMUGONGO
# 4      2011  BUSHENYI MAIN                                    KITABI SEMINARY
# ...     ...            ...                                                ...
# 17634  2016          ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016          ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016          ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016          ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016          ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
# ...

# %%
#Check shape | helps to determine the rows and columns
#Handle conrad
load.shape
# Out:
# (17639, 48)

# %%
# Preparation and Preprocessing or data cleaning
load.columns
# Out:
# Index(['YEAR', 'DISTRICT ', 'SCHOOL', 'TOTAL CANDIDATES', 'TOTAL DIV 1',
#        '% DIV 1', 'TOTAL DIV 2', '% DIV 2', 'TOTAL DIV 3', '% DIV 3',
#        'TOTAL DIV 4', '% DIV 4', 'TOTAL DIV 7', '% DIV 7', 'TOTAL DIV 9',
#        '% DIV 9', 'TOTAL X', '% X', 'FEMALE CANDIDATES', 'FEMALE TOTAL DIV1 ',
#        'FEMALE % DIV1 ', 'FEMALE TOTAL DIV2 ', 'FEMALE % DIV2',
#        'FEMALE TOTAL DIV3', 'FEMALE % DIV3', 'FEMALE TOTAL DIV4',
#        'FEMALE % DIV4', 'FEMALE TOTAL DIV7', 'FEMALE % DIV7',
#        'FEMALE TOTAL DIV9', 'FEMALE % DIV9', 'FEMALE TOTAL X', 'FEMALE % X ',
#        'MALE CANDIDATES', 'MALE TOTAL DIV1 ', 'MALE % DIV1 ',
#        'MALE TOTAL DIV2 ', 'MALE % DIV2', 'MALE TOTAL DIV3', 'MALE % DIV3',
#        'MALE TOTAL DIV4', 'MALE % DIV4 ', 'MALE TOTAL DIV7 ', 'MALE % DIV7',
#        'MALE TOTAL DIV9 ', 'MALE % DIV9', 'MALE TOTAL X ', 'MALE % X'],
#       dtype='object')

# %%
# Removing white spaces
load.columns = load.columns.to_series().apply(lambda x: x.strip())
load.columns
# Out:
# Index(['YEAR', 'DISTRICT', 'SCHOOL', 'TOTAL CANDIDATES', 'TOTAL DIV 1',
#        '% DIV 1', 'TOTAL DIV 2', '% DIV 2', 'TOTAL DIV 3', '% DIV 3',
#        'TOTAL DIV 4', '% DIV 4', 'TOTAL DIV 7', '% DIV 7', 'TOTAL DIV 9',
#        '% DIV 9', 'TOTAL X', '% X', 'FEMALE CANDIDATES', 'FEMALE TOTAL DIV1',
#        'FEMALE % DIV1', 'FEMALE TOTAL DIV2', 'FEMALE % DIV2',
#        'FEMALE TOTAL DIV3', 'FEMALE % DIV3', 'FEMALE TOTAL DIV4',
#        'FEMALE % DIV4', 'FEMALE TOTAL DIV7', 'FEMALE % DIV7',
#        'FEMALE TOTAL DIV9', 'FEMALE % DIV9', 'FEMALE TOTAL X', 'FEMALE % X',
#        'MALE CANDIDATES', 'MALE TOTAL DIV1', 'MALE % DIV1', 'MALE TOTAL DIV2',
#        'MALE % DIV2', 'MALE TOTAL DIV3', 'MALE % DIV3', 'MALE TOTAL DIV4',
#        'MALE % DIV4', 'MALE TOTAL DIV7', 'MALE % DIV7', 'MALE TOTAL DIV9',
#        'MALE % DIV9', 'MALE TOTAL X', 'MALE % X'],
#       dtype='object')

# %%
#By ARIHO
# Replace column names with underscores 
load.columns = load.columns.str.replace(' ', '_')
load.columns
# Out:
# Index(['YEAR', 'DISTRICT', 'SCHOOL', 'TOTAL_CANDIDATES', 'TOTAL_DIV_1',
#        '%_DIV_1', 'TOTAL_DIV_2', '%_DIV_2', 'TOTAL_DIV_3', '%_DIV_3',
#        'TOTAL_DIV_4', '%_DIV_4', 'TOTAL_DIV_7', '%_DIV_7', 'TOTAL_DIV_9',
#        '%_DIV_9', 'TOTAL_X', '%_X', 'FEMALE_CANDIDATES', 'FEMALE_TOTAL_DIV1',
#        'FEMALE_%_DIV1', 'FEMALE_TOTAL_DIV2', 'FEMALE_%_DIV2',
#        'FEMALE_TOTAL_DIV3', 'FEMALE_%_DIV3', 'FEMALE_TOTAL_DIV4',
#        'FEMALE_%_DIV4', 'FEMALE_TOTAL_DIV7', 'FEMALE_%_DIV7',
#        'FEMALE_TOTAL_DIV9', 'FEMALE_%_DIV9', 'FEMALE_TOTAL_X', 'FEMALE_%_X',
#        'MALE_CANDIDATES', 'MALE_TOTAL_DIV1', 'MALE_%_DIV1', 'MALE_TOTAL_DIV2',
#        'MALE_%_DIV2', 'MALE_TOTAL_DIV3', 'MALE_%_DIV3', 'MALE_TOTAL_DIV4',
#        'MALE_%_DIV4', 'MALE_TOTAL_DIV7', 'MALE_%_DIV7', 'MALE_TOTAL_DIV9',
#        'MALE_%_DIV9', 'MALE_TOTAL_X', 'MALE_%_X'],
#       dtype='object')

# %%
# Check for information
load.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17639 entries, 0 to 17638
# Data columns (total 48 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   YEAR               17639 non-null  int64
#  1   DISTRICT           17639 non-null  object
#  2   SCHOOL             17638 non-null  object
#  3   TOTAL_CANDIDATES   17368 non-null  float64
#  4   TOTAL_DIV_1        12858 non-null  float64
#  5   %_DIV_1            17639 non-null  float64
#  6   TOTAL_DIV_2        16880 non-null  float64
#  7   %_DIV_2            17639 non-null  float64
#  8   TOTAL_DIV_3        17168 non-null  float64
#  9   %_DIV_3            17639 non-null  float64
#  10  TOTAL_DIV_4        16888 non-null  float64
#  11  %_DIV_4            17639 non-null  float64
#  12  TOTAL_DIV_7        6489 non-null   float64
#  13  %_DIV_7            17639 non-null  float64
#  14  TOTAL_DIV_9        13454 non-null  float64
# ...

# %%
# Check for Duplicates and drop them
# rogers
for isduplicate in load.duplicated():
    if isduplicate:
        print("Duplicates found and dropped")
        load.drop_duplicates(inplace=True)
        
        break

    else:
        pass 
    print('No duplicates found')
    load[load.duplicated()==True]
# Out:
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# No duplicates found
# ...

# %%
# Check foe null and nan values 
load

# %%
# Check for the number of rows that are null 
null_rows = load[load.isna().any(axis=1)]
before_competition = len(null_rows.axes[0])
print("Number of rows that are null values:"+str(before_competition))
# Out:
# Number of rows that are null values:14511

# %%
# Remove rows without school names
load.dropna(thresh=None, subset=['SCHOOL'], inplace=True)

# %%
# Statistics for Data Science 
# Descriptive Statistics, Central Tendency (mean, median, mode,) Measure dispersions(standard)
# Probability
# Inferential Statistics(make predictions, identity, variables and hypothesis)
# Modelling 
# ML
# regression, classification, cluster, anomaly detection

# +256722359866

#Python data correlation analysis 
# use method corr() calculates correlation coefficients betweem all columns in dataframe.
# Strong Positive correlation 1 Strong Negative Correlation -1
# Perfect correlation 1 Perfect Negative Correlation 1
# Good correlation 0.93455 Good Correlation above 0.5 
# Bad correlation: when is less than 0.5 can be 0.0000009757

load = pd.DataFrame({
    'x' : [1,2,3,4,5  ],
    'y' : [6,7,8,9,10],
    'z' : [11,12,13,14,15]
})

correlation = load.corr()
print(correlation)
# Out:
#      x    y    z
# x  1.0  1.0  1.0
# y  1.0  1.0  1.0
# z  1.0  1.0  1.0
